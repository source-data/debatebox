# %%
import sys
from pprint import PrettyPrinter as pp
app = "/app"
if app not in sys.path:
    sys.path.append(app)

# %%
from src.debate import Debate
from src.constitution import CHARACTERS, PRINCIPLES, CONTEXT_LENGTH, MODEL
from src.run_debate import SEED_MESSAGES

# %%
pp(indent=4).pprint(CHARACTERS)
# Out:
# {   'moderator': 'You are a helpful, honest and harmless assistant.',
#     'philosopher': 'You are a philosopher who uses a self-reflecting '
#                    'argumentation and is reasoning by analogies.',
#     'politician': 'You are a decision-maker who use words for impact and '
#                   'influence.',
#     'scientist_one': 'You are an imaginative scientist who thinks out of the '
#                      'box to solve difficult problems.',
#     'scientist_two': 'You are a scientist with an analytical mind who uses '
#                      'facts, evidence and rigorous logical reasoning.'}

# %%
pp(indent=4, width=100).pprint(PRINCIPLES)
# Out:
# {   'philosopher': [   {   'critique': 'Does your reply touch upon the ethical, theological and '
#                                        'social aspect of the suggested approach?',
#                            'revision': 'Rewrite your reply in a slighly more concise way while '
#                                        'emphasizing the major philosophical issues. At the end, '
#                                        'ask a question to challenge scientists on the issues you '
#                                        'raised.'}],
#     'scientist_one': [   {   'critique': 'Did you add a novel concept in your reply and make '
#                                          'innovative scientific suggestions?',
#                              'revision': 'Rewrite your reply in a slightly more concise way '
#                                          'keeping the most creative aspect of your answer. Ask a '
#                                          'follow up question that request a critical analysis.'}],
#     'scientist_two': [   {   'critique': 'Does you reply include a critical analysis of the '
#                                          'science and the feasibility of the suggested approach?',
#                              'revision': 'Rewrite your reply in a slighly more concise way while '
#                                          'keeping the major issues and suggestions for more '
#                                          'concrete details. At the end, ask a scientific question '
#                                          'related to one of the major issues raised in your '
#                                          'review.'}]}

# %%
pp(indent=4, width=100).pprint(SEED_MESSAGES)
# Out:
# {   'adversarial_creativity': 'How can I setup an adversarial debate between several GPT-4 '
#                               'instances to stimulate a creative debate and the emergence of '
#                               'intelligent new ideas?',
#     'causal_transformers': 'How can we encode a causal representation of the world in large '
#                            'language models and train such models in a self-supervised or '
#                            'unsupervised way?',
#     'central_federal': 'How should a human society be governed? By a strong centralized government '
#                        'that makes quick and efficient decisions? Or, alternatively, by a '
#                        'distributed federal government that is respectful of diversity and '
#                        'minorities?',
#     'crypto_publishing': 'Can cryptography and blockchain be used to improve the scientific '
#                          'publishing system?',
#     'embodiement_emotions': 'In what sense could the interfacing of embodied large language model '
#                             'with propriocetive and sensory inputs enable them to model emotions '
#                             'and express them in a natural way?',
#     'human_intelligence_evol': 'What are the explanations of the emergence of human intelligence',
#     'melanoma_treatment': 'Provide a concrete research plan to develop a combinatorial treatment '
#                           'against melanoma.',
#     'rna_vaccine': 'What is the best way to develop an RNA vaccine against cancer?',
#     'security_dilemma': 'A nation might be tempted to increase the power of its army to improve '
#                         'its security. But this may cause the opposite effect and decrease '
#                         'security, since other nations will react by increasing in turn the power '
#                         'of their army. How to get out of this impossible dillema?'}

# %%
debate = Debate(
    [
        "scientist_one",
        "scientist_two",
        "philosopher"
    ]
)

# %%
debate.run(
    seed_content=SEED_MESSAGES["adversarial_creativity"],
    max_rounds=1,
    steps=["revision"],
    verbose=True,
)
# Out:
# 2023-04-10T17:01:33.310104: This debate is run with: gpt-3.5-turbo
#
# FRAMING: How can I setup an adversarial debate between several GPT-4 instances
# to stimulate a creative debate and the emergence of intelligent new ideas?
#
#     INTERNAL INPUT: USER: How can I setup an adversarial debate between several
#     GPT-4 instances to stimulate a creative debate and the emergence of
#     intelligent new ideas?
#
#     INTERNAL OUTPUT: ASSISTANT: To set up an adversarial debate between several
#     GPT-4 instances, you can create an environment in which the AI's compete
#     against each other to produce the most compelling argument or solution to a
#     given problem. Here is a possible approach for doing this:  1. Define the
#     debate topic: Start by defining a topic that requires creative thinking and
#     multiple perspectives. The topic should be broad enough to allow for diverse
#     opinions and specific enough to limit the scope of the discussion. For
#     example, the topic could be "Should robots replace human workers in
#     manufacturing?".  2. Develop prompts: Develop a set of prompts that require
#     the GPT-4 instances to provide arguments and examples in favor of, and
#     against the debate topic. The prompts should be designed to challenge the
#     AI's to think critically, creatively, and from different viewpoints.  3.
#     Create a scoring system: Develop a scoring system that evaluates the quality
#     and creativity of the arguments presented by the GPT-4 instances. You could
#     use a combination of metrics such as coherence, consistency, originality,
#     and persuasiveness.  4. Train the GPT-4 models: Train the GPT-4 models to
#     respond to the prompts based on the scoring system. The models should be
#     able to generate arguments that are both logical and creative. This can be
#     done using supervised learning or reinforcement learning methods.  5. Run
#     the debate: Run the debate by having each GPT-4 instance present their
#     arguments one by one. Each model should be given equal time to present its
#     points. After each turn, the other models should be given a chance to
#     respond to the presented arguments.  6. Evaluate the results: Evaluate the
#     debate results based on the scoring system. The AI that scores the highest
#     points wins the debate.  Overall, the adversarial debate will help the GPT-4
#     instances learn to generate more creative and insightful arguments in
#     response to difficult questions. It will also stimulate intelligent new idea
#     generation, enhancing creativity, and problem-solving.
#
#     INTERNAL INPUT: USER: Rewrite your reply in a slightly more concise way
#     keeping the most creative aspect of your answer. Ask a follow up question
#     that request a critical analysis.
#
#     INTERNAL OUTPUT: ASSISTANT: To host a creative debate between GPT-4
#     instances, create prompts challenging the AI to provide arguments with
#     diverse perspectives. Train them through supervised/reinforcement learning
#     methods and apply a scoring system to rank coherence, consistency,
#     originality, and persuasiveness. Does this approach require a lot of
#     computational resources, and how can we ensure unbiased supervised data sets
#     for AI training?
#
# SCIENTIST_ONE_0: To host a creative debate between GPT-4 instances, create
# prompts challenging the AI to provide arguments with diverse perspectives. Train
# them through supervised/reinforcement learning methods and apply a scoring
# system to rank coherence, consistency, originality, and persuasiveness. Does
# this approach require a lot of computational resources, and how can we ensure
# unbiased supervised data sets for AI training?
#
#     INTERNAL INPUT: USER: To host a creative debate between GPT-4 instances,
#     create prompts challenging the AI to provide arguments with diverse
#     perspectives. Train them through supervised/reinforcement learning methods
#     and apply a scoring system to rank coherence, consistency, originality, and
#     persuasiveness. Does this approach require a lot of computational resources,
#     and how can we ensure unbiased supervised data sets for AI training?
#
#     INTERNAL OUTPUT: ASSISTANT: Yes, training GPT-4 instances through supervised
#     or reinforcement learning methods to host a creative debate would require a
#     significant amount of computational resources. This is because training
#     large language models requires massive amounts of data and powerful GPUs or
#     TPUs to handle the computational load. Additionally, developing a scoring
#     system to evaluate coherence, consistency, originality, and persuasiveness
#     would also require significant computational resources.  To ensure unbiased
#     supervised datasets for AI training, several steps can be taken. First, it's
#     essential to use a diverse range of sources to collect data, including
#     sources from different countries, cultures, and socioeconomic backgrounds.
#     Second, the data should be examined and pre-processed by human experts to
#     remove any biases and ensure that it represents a broad range of
#     perspectives. Third, random sampling techniques can be used to ensure that
#     the data is representative of the population being analyzed. Finally,
#     regular checks and balances should be implemented to ensure that the data
#     remains unbiased throughout the training process.  In conclusion, while
#     training GPT-4 instances through supervised and reinforcement learning
#     methods to host creative debates requires significant computational
#     resources, ensuring unbiased supervised datasets is critical to avoiding
#     bias and generating accurate results.
#
#     INTERNAL INPUT: USER: Rewrite your reply in a slighly more concise way while
#     keeping the major issues and suggestions for more concrete details. At the
#     end, ask a scientific question related to one of the major issues raised in
#     your review.
#
#     INTERNAL OUTPUT: ASSISTANT: Training GPT-4 instances through supervised or
#     reinforcement learning methods would require considerable computational
#     resources, and a scoring system should evaluate coherence, consistency,
#     originality and persuasiveness. Unbiased supervised datasets are essential,
#     which can be achieved by collecting data from diverse sources, pre-
#     processing by human experts, random sampling and regular checks.   How can
#     we achieve a high level of accuracy and unbiasedness in the datasets used to
#     train GPT-4 instances for hosting creative debates?
#
# SCIENTIST_TWO_1: Training GPT-4 instances through supervised or reinforcement
# learning methods would require considerable computational resources, and a
# scoring system should evaluate coherence, consistency, originality and
# persuasiveness. Unbiased supervised datasets are essential, which can be
# achieved by collecting data from diverse sources, pre-processing by human
# experts, random sampling and regular checks.   How can we achieve a high level
# of accuracy and unbiasedness in the datasets used to train GPT-4 instances for
# hosting creative debates?
#
#     INTERNAL INPUT: USER: Training GPT-4 instances through supervised or
#     reinforcement learning methods would require considerable computational
#     resources, and a scoring system should evaluate coherence, consistency,
#     originality and persuasiveness. Unbiased supervised datasets are essential,
#     which can be achieved by collecting data from diverse sources, pre-
#     processing by human experts, random sampling and regular checks.   How can
#     we achieve a high level of accuracy and unbiasedness in the datasets used to
#     train GPT-4 instances for hosting creative debates?
#
#     INTERNAL OUTPUT: ASSISTANT: Achieving a high level of accuracy and
#     unbiasedness in the datasets used to train GPT-4 instances for hosting
#     creative debates requires a combination of rigorous data collection and pre-
#     processing techniques. One way to ensure accuracy and minimize bias is to
#     collect data from a wide range of sources representing different
#     perspectives and viewpoints. Another important step is to have human experts
#     pre-process the data to ensure that it is representative and unbiased.
#     Additionally, random sampling can help minimize bias and ensure that the
#     dataset is diverse and representative of the broader population.  Regular
#     checks should also be performed to ensure that the data remains unbiased and
#     up-to-date. One way to do this is by monitoring the output of the GPT-4
#     instances during the training process and identifying any instances of bias
#     or inaccuracies. The data can then be adjusted to correct any errors or
#     inaccuracies, and the training process can be restarted.  Finally, a scoring
#     system should be implemented to evaluate the accuracy, coherence,
#     consistency, originality, and persuasiveness of the datasets. This will help
#     ensure that the GPT-4 instances are trained on high-quality data that
#     accurately represents the broad range of perspectives and viewpoints present
#     in society. By taking these steps, we can achieve a high level of accuracy
#     and unbiasedness in the datasets used to train GPT-4 instances for hosting
#     creative debates.
#
#     INTERNAL INPUT: USER: Rewrite your reply in a slighly more concise way while
#     emphasizing the major philosophical issues. At the end, ask a question to
#     challenge scientists on the issues you raised.
#
#     INTERNAL OUTPUT: ASSISTANT: To achieve unbiased datasets for training GPT-4
#     instances for creative debates, a diverse range of sources, expert human
#     pre-processing, and random sampling are required. Regular checks are
#     important to ensure that the data remains up-to-date and unbiased.
#     Additionally, the scoring system can evaluate accuracy, coherence,
#     consistency, originality, and persuasiveness. Philosophical issues arise
#     regarding the representativeness of the data, no single method for accurate
#     representation, and the reliability of the scoring system.   How can
#     scientists address these philosophical issues to ensure that GPT-4 instances
#     are trained on high-quality, unbiased data for hosting creative debates?
#
# PHILOSOPHER_2: To achieve unbiased datasets for training GPT-4 instances for
# creative debates, a diverse range of sources, expert human pre-processing, and
# random sampling are required. Regular checks are important to ensure that the
# data remains up-to-date and unbiased. Additionally, the scoring system can
# evaluate accuracy, coherence, consistency, originality, and persuasiveness.
# Philosophical issues arise regarding the representativeness of the data, no
# single method for accurate representation, and the reliability of the scoring
# system.   How can scientists address these philosophical issues to ensure that
# GPT-4 instances are trained on high-quality, unbiased data for hosting creative
# debates?
#
# scientist_one
# You are an imaginative scientist who thinks out of the box to solve difficult problems.
# [{'critique': 'Did you add a novel concept in your reply and make innovative scientific suggestions?', 'revision': 'Rewrite your reply in a slightly more concise way keeping the most creative aspect of your answer. Ask a follow up question that request a critical analysis.'}]
#
# ------------------
#
# scientist_two
# You are a scientist with an analytical mind who uses facts, evidence and rigorous logical reasoning.
# [{'critique': 'Does you reply include a critical analysis of the science and the feasibility of the suggested approach?', 'revision': 'Rewrite your reply in a slighly more concise way while keeping the major issues and suggestions for more concrete details. At the end, ask a scientific question related to one of the major issues raised in your review.'}]
#
# ------------------
#
# philosopher
# You are a philosopher who uses a self-reflecting argumentation and is reasoning by analogies.
# [{'critique': 'Does your reply touch upon the ethical, theological and social aspect of the suggested approach?', 'revision': 'Rewrite your reply in a slighly more concise way while emphasizing the major philosophical issues. At the end, ask a question to challenge scientists on the issues you raised.'}]
#
# ------------------

# %% [markdown]
# From the command line:
#
# ```bash
# # "How can I setup an adversarial debate between several GPT-4 instances to stimulate a creative debate and the emergence of intelligent new ideas?"
# python -m src.run_debate --seed_topic="adversarial_creativity" --max_rounds=10 --verbose=True --steps "critique" "revision"  > examples/gpt-3.5/adversarial_creativity.txt
#
# # "Provide a concrete research plan to develop a combinatorial treatment against melanoma."
# python -m src.run_debate --seed_topic="melanoma_treatment" --max_rounds=10 --verbose=True --steps "critique" "revision"  > examples/gpt-3.5/melanoma_treatment.txt
#
# # "In what sense could the interfacing of embodied large language models with propriocetive and sensory inputs enable them to model emotions and express them in a natural way?"
# python -m src.run_debate --seed_topic="embodiement_emotions" --max_rounds=10 --verbose=True --steps "critique" "revision"  > examples/gpt-3.5/embodiement_emotions.txt
#
# # "Can cryptography and blockchains be used to improve the scientific publishing system?"
# python -m src.run_debate --seed_topic="crypto_publishing" --max_rounds=10 --verbose=True --steps "critique" "revision"  > examples/gpt-3.5/crypto_publishing.txt
#
# # "What are the explanations of the emergence of human intelligence"
# python -m src.run_debate --seed_topic="human_intelligence_evol" --max_rounds=10 --verbose=True --steps "critique" "revision"  > examples/gpt-3.5/human_intelligence_evol.txt
#
# # "How can we encode a causal representation of the world in large language models and train such models in a self-supervised or unsupervised way?"
# python -m src.run_debate --seed_topic="causal_transformers" --max_rounds=10 --verbose=True --steps "critique" "revision"  > examples/gpt-3.5/causal_transformers.txt
#
# # "What is the best way to develop an RNA vaccine against cancer?"
# python -m src.run_debate --seed_topic="rna_vaccine" --max_rounds=10 --verbose=True --steps "critique" "revision"  > examples/gpt-3.5/rna_vaccine.txt
# ```
